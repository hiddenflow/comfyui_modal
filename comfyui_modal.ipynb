# %%
import os
# select GPU to use [T4, L4, A10, L40S, A100-40GB, A100-80GB, H100, H200, B200] (default on comfyui_app.py is A100-40GB)
os.environ['MODAL_GPU_TYPE'] = 'A100-80GB' 

from google.colab import userdata
#modal token_id = ak-xxxxxxxxxxxxxxxxxx
token_id = userdata.get('token_id')
#modal token_secret = as-xxxxxxxxxxxxxxx
token_secret = userdata.get('token_secret')

# !pip install modal
# !modal token set --token-id {token_id} --token-secret {token_secret}
# !wget http://raw.githubusercontent.com/hiddenflow/comfyui_modal/refs/heads/main/comfyui_app_a100.py -O /content/comfyui_app.py
# !modal deploy comfyui_app.py
